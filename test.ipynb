# %%
import scipy.io
import numpy as np
import pandas as pd
from IPython.display import display, HTML

def preview_mat_file(file_path, num_rows=20):
    """
    读取.mat文件并在Jupyter中以表格形式预览其内容
    
    参数:
    file_path (str): .mat文件的路径
    num_rows (int): 要预览的行数，默认为20
    """
    try:
        # 读取.mat文件
        mat_contents = scipy.io.loadmat(file_path)
        
        # 遍历所有变量
        for key in mat_contents:
            # 跳过系统变量
            if key.startswith('__'):
                continue
                
            data = mat_contents[key]
            
            # 打印变量基本信息
            print(f"/n{'='*50}")
            print(f"变量名: {key}")
            print(f"形状: {data.shape}")
            print(f"数据类型: {data.dtype}")
            print(f"{'='*50}")
            
            # 如果是2D数组，转换为DataFrame并美化显示
            if len(data.shape) == 2:
                df = pd.DataFrame(data[:num_rows])
                
                # 设置列名
                df.columns = [f'列_{i}' for i in range(df.shape[1])]
                
                # 添加行索引列
                df.index.name = '行号'
                df.index = range(1, len(df) + 1)
                
                # 设置显示选项
                pd.set_option('display.max_columns', None)  # 显示所有列
                pd.set_option('display.max_rows', num_rows) # 限制显示行数
                pd.set_option('display.width', None)        # 自动调整宽度
                pd.set_option('display.float_format', lambda x: '%.3f' % x)  # 设置浮点数格式
                
                # 显示DataFrame，使用styler美化
                styled_df = df.style.set_properties(**{
                    'background-color': '#f5f5f5',
                    'border-color': 'black',
                    'border-style': 'solid',
                    'border-width': '1px',
                    'text-align': 'center'
                }).set_table_styles([
                    {'selector': 'th',
                     'props': [('background-color', '#4CAF50'),
                              ('color', 'white'),
                              ('font-weight', 'bold'),
                              ('text-align', 'center'),
                              ('border', '1px solid black')]},
                    {'selector': 'td',
                     'props': [('border', '1px solid black')]}
                ])
                
                display(styled_df)
            else:
                print(f"注意：此变量是{len(data.shape)}维数组，无法以表格形式显示。")
                
    except Exception as e:
        print(f"读取文件时发生错误: {str(e)}")

file_path = 'amigo/data_preprocessed/Data_Preprocessed_P01/Data_Preprocessed_P01.mat'
preview_mat_file(file_path)
# Out:
# /n==================================================
# 变量名: VideoIDs
# 形状: (1, 20)
# 数据类型: object
# ==================================================
# <style type="text/css">
# #T_35b67 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_35b67 td {
#   border: 1px solid black;
# }
# #T_35b67_row0_col0, #T_35b67_row0_col1, #T_35b67_row0_col2, #T_35b67_row0_col3, #T_35b67_row0_col4, #T_35b67_row0_col5, #T_35b67_row0_col6, #T_35b67_row0_col7, #T_35b67_row0_col8, #T_35b67_row0_col9, #T_35b67_row0_col10, #T_35b67_row0_col11, #T_35b67_row0_col12, #T_35b67_row0_col13, #T_35b67_row0_col14, #T_35b67_row0_col15, #T_35b67_row0_col16, #T_35b67_row0_col17, #T_35b67_row0_col18, #T_35b67_row0_col19 {
#   background-color: #f5f5f5;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
#   text-align: center;
# }
# </style>
# <table id="T_35b67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35b67_level0_col0" class="col_heading level0 col0" >列_0</th>
#       <th id="T_35b67_level0_col1" class="col_heading level0 col1" >列_1</th>
#       <th id="T_35b67_level0_col2" class="col_heading level0 col2" >列_2</th>
#       <th id="T_35b67_level0_col3" class="col_heading level0 col3" >列_3</th>
#       <th id="T_35b67_level0_col4" class="col_heading level0 col4" >列_4</th>
#       <th id="T_35b67_level0_col5" class="col_heading level0 col5" >列_5</th>
#       <th id="T_35b67_level0_col6" class="col_heading level0 col6" >列_6</th>
#       <th id="T_35b67_level0_col7" class="col_heading level0 col7" >列_7</th>
#       <th id="T_35b67_level0_col8" class="col_heading level0 col8" >列_8</th>
#       <th id="T_35b67_level0_col9" class="col_heading level0 col9" >列_9</th>
#       <th id="T_35b67_level0_col10" class="col_heading level0 col10" >列_10</th>
#       <th id="T_35b67_level0_col11" class="col_heading level0 col11" >列_11</th>
#       <th id="T_35b67_level0_col12" class="col_heading level0 col12" >列_12</th>
#       <th id="T_35b67_level0_col13" class="col_heading level0 col13" >列_13</th>
#       <th id="T_35b67_level0_col14" class="col_heading level0 col14" >列_14</th>
#       <th id="T_35b67_level0_col15" class="col_heading level0 col15" >列_15</th>
#       <th id="T_35b67_level0_col16" class="col_heading level0 col16" >列_16</th>
#       <th id="T_35b67_level0_col17" class="col_heading level0 col17" >列_17</th>
#       <th id="T_35b67_level0_col18" class="col_heading level0 col18" >列_18</th>
#       <th id="T_35b67_level0_col19" class="col_heading level0 col19" >列_19</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35b67_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_35b67_row0_col0" class="data row0 col0" >['10']</td>
#       <td id="T_35b67_row0_col1" class="data row0 col1" >['13']</td>
#       <td id="T_35b67_row0_col2" class="data row0 col2" >['138']</td>
#       <td id="T_35b67_row0_col3" class="data row0 col3" >['18']</td>
#       <td id="T_35b67_row0_col4" class="data row0 col4" >['19']</td>
#       <td id="T_35b67_row0_col5" class="data row0 col5" >['20']</td>
#       <td id="T_35b67_row0_col6" class="data row0 col6" >['23']</td>
#       <td id="T_35b67_row0_col7" class="data row0 col7" >['30']</td>
#       <td id="T_35b67_row0_col8" class="data row0 col8" >['31']</td>
#       <td id="T_35b67_row0_col9" class="data row0 col9" >['34']</td>
#       <td id="T_35b67_row0_col10" class="data row0 col10" >['36']</td>
#       <td id="T_35b67_row0_col11" class="data row0 col11" >['4']</td>
#       <td id="T_35b67_row0_col12" class="data row0 col12" >['5']</td>
#       <td id="T_35b67_row0_col13" class="data row0 col13" >['58']</td>
#       <td id="T_35b67_row0_col14" class="data row0 col14" >['80']</td>
#       <td id="T_35b67_row0_col15" class="data row0 col15" >['9']</td>
#       <td id="T_35b67_row0_col16" class="data row0 col16" >['N1']</td>
#       <td id="T_35b67_row0_col17" class="data row0 col17" >['P1']</td>
#       <td id="T_35b67_row0_col18" class="data row0 col18" >['B1']</td>
#       <td id="T_35b67_row0_col19" class="data row0 col19" >['U1']</td>
#     </tr>
#   </tbody>
# </table>
# /n==================================================
# 变量名: joined_data
# 形状: (1, 20)
# 数据类型: object
# ==================================================
# <style type="text/css">
# #T_34fc7 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_34fc7 td {
#   border: 1px solid black;
# }
# #T_34fc7_row0_col0, #T_34fc7_row0_col1, #T_34fc7_row0_col2, #T_34fc7_row0_col3, #T_34fc7_row0_col4, #T_34fc7_row0_col5, #T_34fc7_row0_col6, #T_34fc7_row0_col7, #T_34fc7_row0_col8, #T_34fc7_row0_col9, #T_34fc7_row0_col10, #T_34fc7_row0_col11, #T_34fc7_row0_col12, #T_34fc7_row0_col13, #T_34fc7_row0_col14, #T_34fc7_row0_col15, #T_34fc7_row0_col16, #T_34fc7_row0_col17, #T_34fc7_row0_col18, #T_34fc7_row0_col19 {
#   background-color: #f5f5f5;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
#   text-align: center;
# }
# </style>
# <table id="T_34fc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34fc7_level0_col0" class="col_heading level0 col0" >列_0</th>
#       <th id="T_34fc7_level0_col1" class="col_heading level0 col1" >列_1</th>
#       <th id="T_34fc7_level0_col2" class="col_heading level0 col2" >列_2</th>
#       <th id="T_34fc7_level0_col3" class="col_heading level0 col3" >列_3</th>
#       <th id="T_34fc7_level0_col4" class="col_heading level0 col4" >列_4</th>
#       <th id="T_34fc7_level0_col5" class="col_heading level0 col5" >列_5</th>
#       <th id="T_34fc7_level0_col6" class="col_heading level0 col6" >列_6</th>
#       <th id="T_34fc7_level0_col7" class="col_heading level0 col7" >列_7</th>
#       <th id="T_34fc7_level0_col8" class="col_heading level0 col8" >列_8</th>
#       <th id="T_34fc7_level0_col9" class="col_heading level0 col9" >列_9</th>
#       <th id="T_34fc7_level0_col10" class="col_heading level0 col10" >列_10</th>
#       <th id="T_34fc7_level0_col11" class="col_heading level0 col11" >列_11</th>
#       <th id="T_34fc7_level0_col12" class="col_heading level0 col12" >列_12</th>
#       <th id="T_34fc7_level0_col13" class="col_heading level0 col13" >列_13</th>
#       <th id="T_34fc7_level0_col14" class="col_heading level0 col14" >列_14</th>
#       <th id="T_34fc7_level0_col15" class="col_heading level0 col15" >列_15</th>
#       <th id="T_34fc7_level0_col16" class="col_heading level0 col16" >列_16</th>
#       <th id="T_34fc7_level0_col17" class="col_heading level0 col17" >列_17</th>
#       <th id="T_34fc7_level0_col18" class="col_heading level0 col18" >列_18</th>
#       <th id="T_34fc7_level0_col19" class="col_heading level0 col19" >列_19</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34fc7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_34fc7_row0_col0" class="data row0 col0" >[[ 9.73663478e-06  5.78764215e-06 -1.07347318e-05 ... -1.66402336e+01
#   -1.15555038e+01 -8.94009937e+03]
#  [-4.13422856e+00 -4.42354690e+00 -2.49054868e+00 ... -1.68301383e+01
#   -1.41568617e+01 -1.04232609e+04]
#  [-1.82200587e+01 -2.91480700e+00 -5.20181494e+00 ... -8.55812234e+00
#   -9.69310806e+00  9.87280942e+03]
#  ...
#  [-9.87916955e+00  3.71242416e+00  4.37442170e+00 ...  1.05324643e+01
#    2.15396787e+01  4.02338426e+05]
#  [-1.20316206e+00  2.51541484e+00  2.33356999e+00 ...  8.92737830e+00
#    2.21964265e+01  4.02051581e+05]
#  [ 6.66026951e-06  6.91120886e-06 -9.87531174e-06 ...  8.42493274e+00
#    1.78856856e+01  4.02113017e+05]]</td>
#       <td id="T_34fc7_row0_col1" class="data row0 col1" >[[ 8.56684233e-06  6.51970573e-06 -1.05969983e-05 ...  2.94796493e+00
#    7.48186313e+00  4.00532927e+05]
#  [-4.36757986e+00  4.26448741e+00  5.41352484e+00 ...  4.98174490e-01
#    5.30716228e+00  4.00188462e+05]
#  [-1.66805335e+00  5.85616454e+00  8.66718601e+00 ...  1.87805052e+00
#    8.19704470e-01  4.04042899e+05]
#  ...
#  [ 1.94080441e+01  6.53107539e+00  1.01064844e+01 ... -5.19676849e+01
#   -3.54329118e+01  3.79276549e+05]
#  [ 3.82541590e+00  3.54161657e+00  6.35359094e+00 ... -5.44533872e+01
#   -3.65831148e+01  3.79350750e+05]
#  [ 9.85738761e-06  6.78007889e-06 -1.02970031e-05 ... -4.02803787e+01
#   -2.66037360e+01  3.79948056e+05]]</td>
#       <td id="T_34fc7_row0_col2" class="data row0 col2" >[[ 6.94139703e-06  5.64707838e-06 -9.54135489e-06 ... -4.86987835e+01
#   -3.39161944e+01  3.81482256e+05]
#  [ 1.41034708e+01  1.22950546e+00 -2.71669843e+00 ... -5.83733622e+01
#   -4.53354887e+01  3.81466162e+05]
#  [ 1.61863468e+01 -1.86278458e+00 -4.11597355e+00 ... -4.44346636e+01
#   -3.82762317e+01  3.78114921e+05]
#  ...
#  [-1.91965914e+01  2.79011393e+00 -3.49766465e-01 ...  2.36296135e+01
#    2.09695394e+01  4.14529159e+05]
#  [-1.55686831e+01  2.60362626e+00 -2.81180424e+00 ...  2.11353384e+01
#    2.63758126e+01  4.14862218e+05]
#  [ 1.09111441e-05  6.35461405e-06 -1.01149305e-05 ...  1.27411912e+01
#    1.79310255e+01  4.15059473e+05]]</td>
#       <td id="T_34fc7_row0_col3" class="data row0 col3" >[[ 6.27820019e-06  6.33102954e-06 -9.42531912e-06 ... -4.65925253e+01
#    1.12271910e+01  4.18865346e+05]
#  [ 1.37808627e+01  3.43675935e-02 -1.07640279e+00 ... -6.26401981e+01
#    1.25001792e+01  4.19481304e+05]
#  [ 1.78626614e+01  1.09701780e-01 -4.68202897e+00 ... -4.98113519e+01
#    8.49985890e+00  4.10612265e+05]
#  ...
#  [ 7.11458356e+00 -1.08652899e+01 -6.64939389e+00 ...  5.06587672e+01
#    1.93529030e+01  3.29857654e+05]
#  [ 3.71784630e+00 -7.84960968e+00 -3.94890924e+00 ...  5.76492474e+01
#    2.76201337e+01  3.30643631e+05]
#  [ 6.31970897e-06  6.20084296e-06 -1.00705917e-05 ...  4.25965652e+01
#    2.24245272e+01  3.30969647e+05]]</td>
#       <td id="T_34fc7_row0_col4" class="data row0 col4" >[[ 8.36212879e-06  5.74707673e-06 -8.86023392e-06 ... -2.25544284e+00
#    3.56713123e+00  3.31446827e+05]
#  [ 9.38770778e+00  5.73534133e+00  4.48064691e+00 ... -8.76189998e+00
#   -1.13735438e+00  3.31342239e+05]
#  [ 4.38998220e+01  3.74052222e+00 -1.33549132e+00 ... -1.62264600e+01
#   -2.99083514e+00  3.29388832e+05]
#  ...
#  [ 1.75191278e+00  7.39427381e+00 -6.61174644e-01 ...  2.68265439e+01
#    3.13072989e+01  3.42264683e+05]
#  [ 5.71011197e+00  3.91688298e+00 -1.39347860e+00 ...  3.02398593e+01
#    3.45007379e+01  3.42369678e+05]
#  [ 8.58759675e-06  6.91026543e-06 -9.78380383e-06 ...  2.04826306e+01
#    2.47108631e+01  3.42447616e+05]]</td>
#       <td id="T_34fc7_row0_col5" class="data row0 col5" >[[ 1.08696353e-05  6.64328861e-06 -1.01432320e-05 ... -3.21037868e+01
#   -1.18015103e+01  3.39046395e+05]
#  [-4.70995628e+00 -8.27496501e-01  3.58957890e+00 ... -4.14902874e+01
#   -1.09735085e+01  3.38656739e+05]
#  [-5.71895357e+00 -2.57150357e+00  1.13439298e+00 ... -3.45526332e+01
#   -1.06675898e+01  3.46368184e+05]
#  ...
#  [-6.87468134e-01 -1.49113397e+00  2.09822487e+00 ... -2.55722133e+02
#   -2.63658603e+02  2.58718600e+05]
#  [-2.00958145e+00 -1.90030586e+00  2.20257701e+00 ... -2.78755374e+02
#   -2.82092971e+02  2.58898780e+05]
#  [ 1.30563923e-05  8.64514304e-06 -8.32628021e-06 ... -2.04125322e+02
#   -2.09125222e+02  2.59088382e+05]]</td>
#       <td id="T_34fc7_row0_col6" class="data row0 col6" >[[ 1.05951115e-05  8.48193809e-06 -9.07060785e-06 ... -5.35205979e+01
#   -1.59681490e+01  2.58932398e+05]
#  [-5.11278021e+00  3.80852447e+00 -2.53774779e-01 ... -6.48347147e+01
#   -1.85224418e+01  2.58613685e+05]
#  [-1.57644692e+01  2.08116758e+00 -9.11336334e-01 ... -5.61078288e+01
#   -1.70395106e+01  2.58408659e+05]
#  ...
#  [ 7.90879630e+00  3.46683006e+00  5.74597014e+00 ...  7.89118436e+00
#    1.42430830e+01  3.49890055e+05]
#  [ 2.41612720e+00  9.64326777e-01  2.87295285e+00 ... -5.80505511e+00
#    1.63274620e+01  3.50084230e+05]
#  [ 8.92910072e-06  6.30084135e-06 -1.02611546e-05 ... -9.60702427e+00
#    1.05351695e+01  3.49763367e+05]]</td>
#       <td id="T_34fc7_row0_col7" class="data row0 col7" >[[ 5.76122743e-06  6.73857012e-06 -8.11967978e-06 ... -6.69669496e+00
#    2.62430105e+01  3.51965286e+05]
#  [ 1.57259926e+01  3.03077911e+00 -6.88215522e+00 ...  4.69650006e+00
#    3.73336208e+01  3.52765990e+05]
#  [ 2.11031632e+01  6.97257071e+00 -9.77253688e+00 ...  5.52352046e+00
#    3.15101985e+01  3.47607128e+05]
#  ...
#  [ 5.54874424e+00  6.00808505e+00  3.18621774e+00 ...  5.10439997e+01
#    3.11727634e+01  2.51496026e+05]
#  [ 2.46363537e+00  3.46149414e+00  1.02577060e+00 ...  5.81479975e+01
#    3.77456868e+01  2.51452129e+05]
#  [ 8.22628182e-06  6
# /n==================================================
# 变量名: labels_ext_annotation
# 形状: (1, 20)
# 数据类型: object
# ==================================================
# <style type="text/css">
# #T_515bb th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_515bb td {
#   border: 1px solid black;
# }
# #T_515bb_row0_col0, #T_515bb_row0_col1, #T_515bb_row0_col2, #T_515bb_row0_col3, #T_515bb_row0_col4, #T_515bb_row0_col5, #T_515bb_row0_col6, #T_515bb_row0_col7, #T_515bb_row0_col8, #T_515bb_row0_col9, #T_515bb_row0_col10, #T_515bb_row0_col11, #T_515bb_row0_col12, #T_515bb_row0_col13, #T_515bb_row0_col14, #T_515bb_row0_col15, #T_515bb_row0_col16, #T_515bb_row0_col17, #T_515bb_row0_col18, #T_515bb_row0_col19 {
#   background-color: #f5f5f5;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
#   text-align: center;
# }
# </style>
# <table id="T_515bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_515bb_level0_col0" class="col_heading level0 col0" >列_0</th>
#       <th id="T_515bb_level0_col1" class="col_heading level0 col1" >列_1</th>
#       <th id="T_515bb_level0_col2" class="col_heading level0 col2" >列_2</th>
#       <th id="T_515bb_level0_col3" class="col_heading level0 col3" >列_3</th>
#       <th id="T_515bb_level0_col4" class="col_heading level0 col4" >列_4</th>
#       <th id="T_515bb_level0_col5" class="col_heading level0 col5" >列_5</th>
#       <th id="T_515bb_level0_col6" class="col_heading level0 col6" >列_6</th>
#       <th id="T_515bb_level0_col7" class="col_heading level0 col7" >列_7</th>
#       <th id="T_515bb_level0_col8" class="col_heading level0 col8" >列_8</th>
#       <th id="T_515bb_level0_col9" class="col_heading level0 col9" >列_9</th>
#       <th id="T_515bb_level0_col10" class="col_heading level0 col10" >列_10</th>
#       <th id="T_515bb_level0_col11" class="col_heading level0 col11" >列_11</th>
#       <th id="T_515bb_level0_col12" class="col_heading level0 col12" >列_12</th>
#       <th id="T_515bb_level0_col13" class="col_heading level0 col13" >列_13</th>
#       <th id="T_515bb_level0_col14" class="col_heading level0 col14" >列_14</th>
#       <th id="T_515bb_level0_col15" class="col_heading level0 col15" >列_15</th>
#       <th id="T_515bb_level0_col16" class="col_heading level0 col16" >列_16</th>
#       <th id="T_515bb_level0_col17" class="col_heading level0 col17" >列_17</th>
#       <th id="T_515bb_level0_col18" class="col_heading level0 col18" >列_18</th>
#       <th id="T_515bb_level0_col19" class="col_heading level0 col19" >列_19</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_515bb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_515bb_row0_col0" class="data row0 col0" >[[ 1.          0.05776439 -0.04344884]
#  [ 2.          0.0754513  -0.05363643]
#  [ 3.          0.04945779 -0.10131739]
#  [ 4.         -0.16609842 -0.10942031]
#  [ 5.         -0.02723557 -0.13405643]
#  [ 6.         -0.11332459 -0.09807158]]</td>
#       <td id="T_515bb_row0_col1" class="data row0 col1" >[[ 1.          0.03924277 -0.07822977]
#  [ 2.          0.01664528 -0.09749728]
#  [ 3.          0.12427341 -0.03041396]
#  [ 4.         -0.01868065 -0.05425676]]</td>
#       <td id="T_515bb_row0_col2" class="data row0 col2" >[[ 1.         -0.09449048 -0.07563033]
#  [ 2.         -0.01753671 -0.07874594]
#  [ 3.         -0.02361913 -0.11766087]
#  [ 4.         -0.14101495 -0.06349479]
#  [ 5.         -0.05461204 -0.07555546]
#  [ 6.         -0.09380272 -0.10633539]
#  [ 7.         -0.17464542  0.08236238]]</td>
#       <td id="T_515bb_row0_col3" class="data row0 col3" >[[ 1.         -0.14352697 -0.07305414]
#  [ 2.         -0.06160589 -0.13073575]
#  [ 3.         -0.05633678 -0.1000186 ]
#  [ 4.          0.04070245 -0.10505938]
#  [ 5.          0.1155855  -0.0822996 ]]</td>
#       <td id="T_515bb_row0_col4" class="data row0 col4" >[[ 1.00000000e+00 -4.50326907e-02 -9.59120374e-02]
#  [ 2.00000000e+00 -5.62847019e-02 -6.49712155e-02]
#  [ 3.00000000e+00 -1.08979009e-01 -1.00977465e-01]
#  [ 4.00000000e+00 -1.25801921e-01 -1.65518075e-02]
#  [ 5.00000000e+00 -1.16478335e-01 -1.95772067e-03]
#  [ 6.00000000e+00 -8.33226379e-02 -1.01619188e-01]
#  [ 7.00000000e+00 -1.33843457e-01 -3.00172986e-02]
#  [ 8.00000000e+00 -1.48946272e-01 -6.82598142e-02]]</td>
#       <td id="T_515bb_row0_col5" class="data row0 col5" >[[ 1.         -0.0865745  -0.14385806]
#  [ 2.         -0.0905769  -0.11941631]
#  [ 3.         -0.06204858 -0.09265413]
#  [ 4.         -0.12740716 -0.08539382]
#  [ 5.         -0.26004855  0.14812552]]</td>
#       <td id="T_515bb_row0_col6" class="data row0 col6" >[[ 1.         -0.04181756 -0.15690224]
#  [ 2.         -0.06287724 -0.17553407]
#  [ 3.         -0.08065437 -0.02527971]
#  [ 4.         -0.04465742 -0.0315858 ]
#  [ 5.         -0.09268761 -0.19205054]
#  [ 6.         -0.08450053 -0.15039852]
#  [ 7.         -0.10883346 -0.00762349]]</td>
#       <td id="T_515bb_row0_col7" class="data row0 col7" >[[ 1.         -0.08580862 -0.16509072]
#  [ 2.         -0.07945044  0.00644234]
#  [ 3.         -0.06033918 -0.11867042]
#  [ 4.         -0.25086865  0.20276499]
#  [ 5.         -0.22654502  0.14280573]]</td>
#       <td id="T_515bb_row0_col8" class="data row0 col8" >[[ 1.00000000e+00 -9.35943938e-02 -6.88327149e-02]
#  [ 2.00000000e+00 -1.31590450e-02 -1.68489532e-01]
#  [ 3.00000000e+00 -1.39659422e-01 -3.93869219e-04]
#  [ 4.00000000e+00 -9.72736066e-02 -1.49965124e-01]
#  [ 5.00000000e+00 -6.23717716e-02 -1.05120765e-01]
#  [ 6.00000000e+00 -6.09962520e-02 -1.73449402e-01]
#  [ 7.00000000e+00 -7.66045404e-02 -9.44463045e-02]
#  [ 8.00000000e+00 -1.17031240e-01 -1.28484138e-02]
#  [ 9.00000000e+00 -8.10556811e-02 -2.12338290e-01]]</td>
#       <td id="T_515bb_row0_col9" class="data row0 col9" >[[ 1.         -0.02868921 -0.05375594]
#  [ 2.          0.00521702 -0.15432884]
#  [ 3.         -0.09265087 -0.0921747 ]
#  [ 4.         -0.40440882  0.35075565]
#  [ 5.         -0.4281842   0.40530026]]</td>
#       <td id="T_515bb_row0_col10" class="data row0 col10" >[[ 1.         -0.07145959 -0.11710332]
#  [ 2.         -0.02813166 -0.28204849]
#  [ 3.         -0.01828725 -0.14012211]
#  [ 4.         -0.03906513 -0.21407373]
#  [ 5.         -0.11353431 -0.06277773]]</td>
#       <td id="T_515bb_row0_col11" class="data row0 col11" >[[ 1.00000000e+00  6.96306837e-02 -5.62679613e-02]
#  [ 2.00000000e+00  7.23049952e-02 -5.69710667e-02]
#  [ 3.00000000e+00  1.67216782e-01  3.60690271e-02]
#  [ 4.00000000e+00 -2.13000939e-02 -6.97394976e-02]
#  [ 5.00000000e+00 -1.51595473e-04 -3.20759279e-02]
#  [ 6.00000000e+00  1.49767492e-01  1.61181794e-01]]</td>
#       <td id="T_515bb_row0_col12" class="data row0 col12" >[[1.         0.14739777 0.05150712]
#  [2.         0.13177274 0.04448909]
#  [3.         0.06419929 0.0752904 ]
#  [4.         0.19109632 0.133145  ]
#  [5.         0.18863638 0.11990783]
#  [6.         0.11881876 0.0437046 ]
#  [7.         0.16133804 0.03947109]]</td>
#       <td id="T_515bb_row0_col13" class="data row0 col13" >[[ 1.00000000e+00  7.69691136e-02 -7.11884899e-02]
#  [ 2.00000000e+00  1.70188239e-01  5.77076532e-02]
#  [ 3.00000000e+00 -2.05862932e-02 -3.66251872e-02]
#  [ 4.00000000e+00  1.50977465e-01  2.73104359e-03]]</td>
#       <td id="T_515bb_row0_col14" class="data row0 col14" >[[ 1.00000000e+00 -8.11858858e-02 -1.47105271e-01]
#  [ 2.00000000e+00 -8.58867405e-02 -4.65202794e-03]
#  [ 3.00000000e+00 -8.42187253e-02 -1.40834519e-01]
#  [ 4.00000000e+00  3.13788678e-02 -6.76762181e-02]
#  [ 5.00000000e+00  9.02797541e-02 -3.48483580e-02]
#  [ 6.00000000e+00  1.24008352e-01 -9.85710034e-02]]</td>
#       <td id="T_515bb_row0_col15" class="data row0 col15" >[[ 1.          0.12088065  0.01763623]
#  [ 2.          0.11991248 -0.02795402]
#  [ 3.         -0.01831329 -0.07219479]
#  [ 4.          0.12900031 -0.00731099]
#  [ 5.          0.15115975  0.07082392]]</td>
#       <td id="T_515bb_row0_col16" class="data row0 col16" >[[ 1.00000000e+00  1.88182993e-01  9.24165062e-02]
#  [ 2.00000000e+00  2.11285957e-01  1.15586898e-01]
#  [ 3.00000000e+00  2.38156952e-01  1.58545613e-01]
#  [ 4.00000000e+00  1.67164700e-01  3.50157641e-03]
#  [ 5.00000000e+00 -6.31176585e-02 -1.22871851e-01]
#  [ 6.00000000e+00  1.54474392e-01 -3.65577597e-02]
#  [ 7.00000000e+00 -2.13047441e-02 -3.91823145e-03]
#  [ 8.00000000e+0
# /n==================================================
# 变量名: labels_selfassessment
# 形状: (1, 20)
# 数据类型: object
# ==================================================
# <style type="text/css">
# #T_69b25 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_69b25 td {
#   border: 1px solid black;
# }
# #T_69b25_row0_col0, #T_69b25_row0_col1, #T_69b25_row0_col2, #T_69b25_row0_col3, #T_69b25_row0_col4, #T_69b25_row0_col5, #T_69b25_row0_col6, #T_69b25_row0_col7, #T_69b25_row0_col8, #T_69b25_row0_col9, #T_69b25_row0_col10, #T_69b25_row0_col11, #T_69b25_row0_col12, #T_69b25_row0_col13, #T_69b25_row0_col14, #T_69b25_row0_col15, #T_69b25_row0_col16, #T_69b25_row0_col17, #T_69b25_row0_col18, #T_69b25_row0_col19 {
#   background-color: #f5f5f5;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
#   text-align: center;
# }
# </style>
# <table id="T_69b25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69b25_level0_col0" class="col_heading level0 col0" >列_0</th>
#       <th id="T_69b25_level0_col1" class="col_heading level0 col1" >列_1</th>
#       <th id="T_69b25_level0_col2" class="col_heading level0 col2" >列_2</th>
#       <th id="T_69b25_level0_col3" class="col_heading level0 col3" >列_3</th>
#       <th id="T_69b25_level0_col4" class="col_heading level0 col4" >列_4</th>
#       <th id="T_69b25_level0_col5" class="col_heading level0 col5" >列_5</th>
#       <th id="T_69b25_level0_col6" class="col_heading level0 col6" >列_6</th>
#       <th id="T_69b25_level0_col7" class="col_heading level0 col7" >列_7</th>
#       <th id="T_69b25_level0_col8" class="col_heading level0 col8" >列_8</th>
#       <th id="T_69b25_level0_col9" class="col_heading level0 col9" >列_9</th>
#       <th id="T_69b25_level0_col10" class="col_heading level0 col10" >列_10</th>
#       <th id="T_69b25_level0_col11" class="col_heading level0 col11" >列_11</th>
#       <th id="T_69b25_level0_col12" class="col_heading level0 col12" >列_12</th>
#       <th id="T_69b25_level0_col13" class="col_heading level0 col13" >列_13</th>
#       <th id="T_69b25_level0_col14" class="col_heading level0 col14" >列_14</th>
#       <th id="T_69b25_level0_col15" class="col_heading level0 col15" >列_15</th>
#       <th id="T_69b25_level0_col16" class="col_heading level0 col16" >列_16</th>
#       <th id="T_69b25_level0_col17" class="col_heading level0 col17" >列_17</th>
#       <th id="T_69b25_level0_col18" class="col_heading level0 col18" >列_18</th>
#       <th id="T_69b25_level0_col19" class="col_heading level0 col19" >列_19</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69b25_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_69b25_row0_col0" class="data row0 col0" >[[2.938568 5.       8.235496 1.       1.       1.       0.       0.
#   0.       0.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col1" class="data row0 col1" >[[4.877136 6.542664 4.849832 9.       9.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col2" class="data row0 col2" >[[5.       3.238904 2.774744 1.327648 1.       0.       0.       0.
#   0.       0.       1.       0.      ]]</td>
#       <td id="T_69b25_row0_col3" class="data row0 col3" >[[2.965872 8.59044  8.098976 8.208192 9.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col4" class="data row0 col4" >[[6.460752 1.       2.856656 1.       9.       0.       1.       0.
#   0.       0.       1.       0.      ]]</td>
#       <td id="T_69b25_row0_col5" class="data row0 col5" >[[5.       1.436864 1.       1.40956  9.       0.       0.       0.
#   0.       0.       1.       0.      ]]</td>
#       <td id="T_69b25_row0_col6" class="data row0 col6" >[[6.488056 1.382256 3.402728 1.       9.       0.       1.       0.
#   0.       0.       1.       0.      ]]</td>
#       <td id="T_69b25_row0_col7" class="data row0 col7" >[[9.     6.7884 1.     9.     1.     0.     0.     0.     1.     0.
#   0.     0.    ]]</td>
#       <td id="T_69b25_row0_col8" class="data row0 col8" >[[1.382256 1.382256 8.180888 8.2628   9.       1.       0.       0.
#   0.       0.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col9" class="data row0 col9" >[[6.6      1.       1.027304 1.       9.       0.       1.       1.
#   0.       0.       1.       0.      ]]</td>
#       <td id="T_69b25_row0_col10" class="data row0 col10" >[[6.542664 1.       4.549488 9.       9.       1.       0.       0.
#   0.       0.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col11" class="data row0 col11" >[[4.931744 6.65188  8.044368 8.972696 9.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col12" class="data row0 col12" >[[6.488056 9.       2.829352 9.       9.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col13" class="data row0 col13" >[[5.       6.733792 8.235496 9.       1.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col14" class="data row0 col14" >[[4.959048 6.706488 6.433448 8.53584  1.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col15" class="data row0 col15" >[[3.129696 6.761096 4.713312 9.       9.       0.       0.       0.
#   0.       1.       0.       0.      ]]</td>
#       <td id="T_69b25_row0_col16" class="data row0 col16" >[[7.88 6.6  3.24 7.8  1.64 0.   0.   0.   1.   0.   1.   0.  ]]</td>
#       <td id="T_69b25_row0_col17" class="data row0 col17" >[[6.36 7.88 4.52 7.72 2.28 0.   0.   1.   1.   0.   0.   0.  ]]</td>
#       <td id="T_69b25_row0_col18" class="data row0 col18" >[[6.36 5.   3.32 7.8  2.36 0.   0.   1.   1.   0.   1.   0.  ]]</td>
#       <td id="T_69b25_row0_col19" class="data row0 col19" >[[1.8  3.72 3.08 7.4  2.6  0.   0.   1.   0.   0.   0.   1.  ]]</td>
#     </tr>
#   </tbody>
# </table>
